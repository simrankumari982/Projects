# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
#multiple null values that has to be preprocessed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
#Except date everything is in float data type

# %%
df=df.dropna(axis=0).reset_index()

# %%
#dropped all NaN values

# %%
df.isnull().sum()
# Out:
# index               0
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
df.describe()
# Out:
#              index      station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# count  7588.000000  7588.000000   7588.000000   7588.000000  7588.000000
# mean   3859.164207    13.014101     29.748366     23.195809    56.724969
# std    2232.869924     7.217858      2.967401      2.400880    14.626559
# min       0.000000     1.000000     20.000000     11.300000    19.794666
# 25%    1936.750000     7.000000     27.800000     21.600000    45.960243
# 50%    3843.500000    13.000000     29.900000     23.400000    55.023199
# 75%    5781.250000    19.000000     32.000000     24.800000    67.115099
# max    7749.000000    25.000000     37.600000     29.900000    98.524734
#
#        LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS  \
# count  7588.000000       7588.000000       7588.000000  7588.000000
# mean     88.360823         29.620128         23.511786     7.094097
# std       7.199456          2.943496          2.342579     2.177034
# ...

# %% [markdown]
# Visualization

# %%
df = df.drop(['Date', 'index'], axis = 1)

# %%
plt.figure(figsize=(18, 6), dpi=80)
plt.plot(df["LDAPS_CC1"],label="LDAPS_CC1")
plt.plot(df["LDAPS_CC2"],label="LDAPS_CC2")
plt.plot(df["LDAPS_CC3"],label="LDAPS_CC3")
plt.plot(df["LDAPS_CC4"],label="LDAPS_CC4")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(18, 6), dpi=80)
plt.plot(df["LDAPS_PPT1"],label="LDAPS_PPT1")
plt.plot(df["LDAPS_PPT2"],label="LDAPS_PPT2")
plt.plot(df["LDAPS_PPT3"],label="LDAPS_PPT3")
plt.plot(df["LDAPS_PPT4"],label="LDAPS_PPT4")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(18, 6), dpi=80)
plt.plot(df["Present_Tmax"],label="Present_Tmax")
plt.plot(df["Present_Tmin"],label="Present_Tmin")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(18, 6), dpi=80)
plt.plot(df["Next_Tmax"],label="Next_Tmax")
plt.plot(df["Next_Tmin"],label="Next_Tmin")
plt.legend()
plt.show()

# %%
for col in ["Next_Tmax","Next_Tmin"]:
    plt.figure()
    sns.displot(df[col],kind='kde')
    plt.show()
print(df["Next_Tmax"].mean())
print(df["Next_Tmax"].std())
print(df["Next_Tmin"].mean())
print(df["Next_Tmin"].std())
# Out:
# 30.241526093832377
# 3.111807069134012
# 22.910819715340047
# 2.4822555109068802

# %%
sns.jointplot('Present_Tmax', 'Solar radiation', df, kind='scatter', color='seagreen')

# %%
#This plot tells us that generally higher values of Solar Radiation is Associated with Lower Values of Maximum Temperature

# %%
sns.jointplot('Present_Tmin', 'Solar radiation', df, kind='scatter', color='seagreen')

# %%
#This plots tells us that higher values of Solar Radiation are associated with lower values of minimum temperature

# %%
sns.jointplot('Present_Tmax', 'LDAPS_WS', df, kind='scatter', color='seagreen')

# %%
sns.jointplot('Present_Tmin', 'LDAPS_WS', df, kind='scatter', color='seagreen')

# %%
#This plots tells us that lower values of wind speeds are associated with high temperatures

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#This plot tells us there occurs some very high correlation b/w certain features

# %%
sns.scatterplot(x=df['DEM'],y=df['Present_Tmax'])
# Out:
# <AxesSubplot:xlabel='DEM', ylabel='Present_Tmax'>

# %%
sns.scatterplot(x=df['DEM'],y=df['Present_Tmin'])
# Out:
# <AxesSubplot:xlabel='DEM', ylabel='Present_Tmin'>

# %%
df.skew()
# Out:
# station            -0.004178
# Present_Tmax       -0.257069
# Present_Tmin       -0.353822
# LDAPS_RHmin         0.301396
# LDAPS_RHmax        -0.845264
# LDAPS_Tmax_lapse   -0.222349
# LDAPS_Tmin_lapse   -0.574035
# LDAPS_WS            1.553926
# LDAPS_LH            0.662971
# LDAPS_CC1           0.456716
# LDAPS_CC2           0.473929
# LDAPS_CC3           0.639649
# LDAPS_CC4           0.663815
# LDAPS_PPT1          5.305906
# LDAPS_PPT2          5.710360
# LDAPS_PPT3          6.356670
# LDAPS_PPT4          6.681256
# lat                 0.085377
# lon                -0.289048
# DEM                 1.721617
# Slope               1.559050
# Solar radiation    -0.524325
# Next_Tmax          -0.334842
# Next_Tmin          -0.393662
# dtype: float64

# %%
#There is a lot of skewness in continuous columns

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Slope'])
# Out:
# <AxesSubplot:xlabel='Slope', ylabel='count'>

# %% [markdown]
# All the slope values do not have equal no. of counts

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='DEM',data=df)
# Out:
# <AxesSubplot:xlabel='DEM', ylabel='count'>

# %%
#checking outliers
for i in df.columns:
    sns.boxplot(df[i])
    plt.show()

# %%
#there are alot of outliers in the dataset

# %%
df.drop(['station'],axis=1,inplace=True)

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %%
#data is not normally distributed there is a lot of skewness

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
for i in [3,3.2,3.4,3.6,3.8,4,4.2,4.4,4.6,4.8,5]:
    df_new=df[(z<i).all(axis=1)]
    loss_prcnt=(len(df)-len(df_new))/len(df)
    print(loss_prcnt)
# Out:
# 0.11188719030047443
# 0.09659989457037428
# 0.08447548761201898
# 0.07696362677912494
# 0.06958355297838692
# 0.06312598840274117
# 0.058777016341591985
# 0.05271481286241434
# 0.04823405376910912
# 0.04388508170795994
# 0.04085397996837111

# %%
#We are keeping threshold as 3.4 as we cannot allow loss percent more than 8
df=df[(z<3.6).all(axis=1)]

# %%
df.shape
# Out:
# (7004, 23)

# %%
#latitude is highly colinear hence removing it
df.drop(['lat','lon'],axis=1,inplace=True)

# %%
calc_vif()
# Out:
#              feature         VIF
# 0       Present_Tmax  262.875514
# 1       Present_Tmin  307.507092
# 2        LDAPS_RHmin   98.804688
# 3        LDAPS_RHmax  203.953081
# 4   LDAPS_Tmax_lapse  673.870656
# 5   LDAPS_Tmin_lapse  721.781756
# 6           LDAPS_WS   16.227725
# 7           LDAPS_LH    6.421158
# 8          LDAPS_CC1   10.363712
# 9          LDAPS_CC2   13.729646
# 10         LDAPS_CC3   12.521284
# 11         LDAPS_CC4    6.355855
# 12        LDAPS_PPT1    1.666052
# 13        LDAPS_PPT2    1.515509
# 14        LDAPS_PPT3    1.348359
# 15        LDAPS_PPT4    1.325210
# 16               DEM    6.497104
# 17             Slope    5.096326
# 18   Solar radiation  181.218897

# %%
x=df.iloc[:,:-2]
y=df.iloc[:,-2:]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
ms=StandardScaler()
x=ms.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split

# %%
x_train=x
y_train=y
x_test=x
y_test=y
r_state=0
max_r2=0
lr=LinearRegression()
for i in range(0,2000):
    tr_x,t_x,tr_y,t_y=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(tr_x,tr_y)
    pred=lr.predict(t_x)
    if r2_score(t_y,pred)>max_r2:
        x_train=tr_x
        x_test=t_x
        y_train=tr_y
        y_test=t_y
        r_state=i
        max_r2=r2_score(t_y,pred)
print("At random state",i,"max_r2 is",max_r2)
# Out:
# At random state 1999 max_r2 is 0.8202647126659763

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print("MSE=",mean_squared_error(y_test,pred))
    print("r2 score=",r2_score(y_test,pred))

# %%
from sklearn.model_selection import cross_val_score,KFold
def cvs(m):
    cv1=KFold(n_splits=5,shuffle=True)
    score=cross_val_score(m,x,y,cv=cv1,scoring='r2')
    print("Cross val score",score)
    print(score.mean())

# %%
from sklearn.model_selection import GridSearchCV
def hypertuning(params,model):
    gd=GridSearchCV(model,params,cv=5)
    gd.fit(x,y)
    print(gd.best_params_)

# %%
lr_params={'fit_intercept':[True,False],'normalize':[True,False],'copy_X':[True,False],'n_jobs':[None,1,2,3]}
hypertuning(lr_params,lr)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': True}

# %%
lr=LinearRegression(copy_X=True,fit_intercept=True,n_jobs=None,normalize=True)

# %%
fun(lr)
cvs(lr)
# Out:
# MSE= 1.4821971340679505
# r2 score= 0.8202647126659763
# Cross val score [0.791484   0.79789427 0.78819082 0.80430676 0.7825806 ]
# 0.7928912912985844

# %%
CVS=[79.29]
r2=[82.03]
model=['Linear Regression']

# %%
l=Lasso()
params_lasso={
    'alpha':[0.001,0.01,0.1,1],
    'fit_intercept':[True,False],
    'normalize':[True,False],
    'copy_X':[True,False]
}
hypertuning(params_lasso,l)
# Out:
# {'alpha': 0.01, 'copy_X': True, 'fit_intercept': True, 'normalize': False}

# %%
l=Lasso(alpha=0.01,copy_X=True,fit_intercept=True,normalize=False)
fun(l)
cvs(l)
# Out:
# MSE= 1.4935060659039419
# r2 score= 0.8188854713192193
# Cross val score [0.78825275 0.79670274 0.80576892 0.78904843 0.78263314]
# 0.7924811984022396

# %%
CVS.append(79.25)
r2.append(81.89)
model.append('Lasso')

# %%
R=Ridge()
params_ridge={
    'alpha':[0.001,0.01,0.1,1],
    'fit_intercept':[True,False],
    'normalize':[True,False],
    'copy_X':[True,False]
}
hypertuning(params_ridge,R)
# Out:
# {'alpha': 0.01, 'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %%
R=Ridge(alpha=0.01,copy_X=True,fit_intercept=True,normalize=True)
fun(R)
cvs(R)
# Out:
# MSE= 1.4871301877685363
# r2 score= 0.8197403703291063
# Cross val score [0.78116449 0.79009571 0.8020411  0.78953963 0.80043049]
# 0.7926542847109672

# %%
CVS.append(79.27)
r2.append(81.97)
model.append('Ridge')

# %%
en=ElasticNet()
params_en={
    'alpha':[0.001,0.01,0.1,1],
    'fit_intercept':[True,False],
    'normalize':[True,False],
    'copy_X':[True,False]
}
hypertuning(params_en,en)
# Out:
# {'alpha': 0.01, 'copy_X': True, 'fit_intercept': True, 'normalize': False}

# %%
en=ElasticNet(alpha=0.01,copy_X=True,fit_intercept=True,normalize=False)
fun(en)
cvs(en)
# Out:
# MSE= 1.4895828893628955
# r2 score= 0.8194106815381808
# Cross val score [0.79697546 0.78074988 0.80080686 0.79391118 0.79073649]
# 0.7926359741499063

# %%
CVS.append(79.26)
r2.append(81.94)
model.append('Elastic Net')

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
params_dtr={'criterion':['mse','friedman_mse','mae'],'splitter':['random','best'],'max_depth':[10,12,15],'min_samples_split':[5,10,15]}
hypertuning(params_dtr,dtr)
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 10, 'splitter': 'best'}

# %%
dtr=DecisionTreeRegressor(criterion='friedman_mse',max_depth=10,min_samples_split=10,splitter='best')
fun(dtr)
cvs(dtr)
# Out:
# MSE= 1.614173831764938
# r2 score= 0.8011996108340027
# Cross val score [0.75953585 0.75682389 0.76831852 0.78951095 0.77415292]
# 0.7696684270890061

# %%
CVS.append(80.12)
r2.append(76.97)
model.append('Decision Tree')

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
params_knn={'n_neighbors':[5,7,9,11],'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree','brute'],'leaf_size':[30,40,50]}
hypertuning(params_knn,knn)
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 11, 'weights': 'distance'}

# %%
knn=KNeighborsRegressor(algorithm='auto',leaf_size=30,n_neighbors=11,weights='distance')
fun(knn)
cvs(knn)
# Out:
# MSE= 0.8842613177626034
# r2 score= 0.889141021576836
# Cross val score [0.88525477 0.87938389 0.87627858 0.87784621 0.88991819]
# 0.8817363269488145

# %%
CVS.append(88.15)
r2.append(88.91)
model.append('K Neighbor')

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,HistGradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
rf=RandomForestRegressor()
etr=ExtraTreeRegressor()
ada=AdaBoostRegressor()
Gd=GradientBoostingRegressor()
HGd=HistGradientBoostingRegressor()

# %%
#Hypertuning RF was taking forever hence
fun(rf)
cvs(rf)
# Out:
# MSE= 0.7785689685938608
# r2 score= 0.9023533629333828
# Cross val score [0.88716356 0.89393003 0.89680752 0.89206665 0.88990687]
# 0.8919749250635448

# %%
r2.append(90.24)
CVS.append(89.20)
model.append('Random Forest')

# %%
params_etr={'criterion':['mse','friedman_mse','mae'],
            'splitter':['random','best'],
            'max_depth':[None,1,2,3],
            'min_samples_split':[2,3,4]}
hypertuning(params_etr,etr)
# Out:
# {'criterion': 'mse', 'max_depth': 3, 'min_samples_split': 3, 'splitter': 'best'}

# %%
etr=ExtraTreeRegressor(criterion='mse',max_depth=3,min_samples_split=3,splitter='best')
fun(etr)
cvs(etr)
# Out:
# MSE= 2.730776063139479
# r2 score= 0.6625095178592015
# Cross val score [0.63035692 0.63998212 0.64167682 0.60056283 0.64123824]
# 0.6307633863646471

# %%
CVS.append(63.07)
r2.append(63.08)
model.append('Extra Tree')

# %%
res=pd.DataFrame()
res['Models']=model
res['CVS']=CVS
res['r2']=r2
diff=[]
for i in range(0,len(r2)):
    diff.append(r2[i]-CVS[i])
res['diff']=diff
res
# Out:
#               Models    CVS     r2  diff
# 0  Linear Regression  79.29  82.03  2.74
# 1              Lasso  79.25  81.89  2.64
# 2              Ridge  79.27  81.97  2.70
# 3        Elastic Net  79.26  81.94  2.68
# 4      Decision Tree  80.12  76.97 -3.15
# 5         K Neighbor  88.15  88.91  0.76
# 6      Random Forest  89.20  90.24  1.04
# 7         Extra Tree  63.07  63.08  0.01

# %%
#Best model should be knn as it has highest r2 value with min diff between cross val score

# %%
import pickle
filename='Temprature.pkl'
pickle.dump(knn,open(filename,'wb'))

# %%
predict=knn.predict(x_test)

# %%
y_test
# Out:
#       Next_Tmax  Next_Tmin
# 4172       32.2       23.3
# 1421       31.3       21.4
# 5798       33.0       27.6
# 16         31.5       21.1
# 5356       33.1       25.4
# ...         ...        ...
# 6401       33.7       25.8
# 93         27.4       22.5
# 7046       31.6       24.0
# 1694       29.4       21.6
# 2176       29.8       19.6
#
# [1401 rows x 2 columns]

# %%
predict
# Out:
# array([[31.67196327, 22.77436916],
#        [30.61445116, 21.8985833 ],
#        [33.01102586, 27.04419476],
#        ...,
#        [32.31853576, 24.25188428],
#        [29.56769858, 22.00496101],
#        [31.20462551, 19.50907822]])

# %%
output=pd.DataFrame(predict)

# %%
output
# Out:
#               0          1
# 0     31.671963  22.774369
# 1     30.614451  21.898583
# 2     33.011026  27.044195
# 3     31.331850  22.108765
# 4     31.626604  25.667297
# ...         ...        ...
# 1396  33.346942  25.436571
# 1397  28.331982  22.859914
# 1398  32.318536  24.251884
# 1399  29.567699  22.004961
# 1400  31.204626  19.509078
#
# [1401 rows x 2 columns]

# %%
output.to_csv('Tempreture_Forcast.csv')
