# %%
import pandas as pd
df=pd.read_csv('Happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# EDA

# %%
df['Country'].value_counts()
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64

# %% [markdown]
# Scatterplot

# %%
import seaborn as sns
sns.scatterplot(x='Family',y='Happiness Score',data=df)

# %% [markdown]
# We can see Family is between the range 0-1.4

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)

# %% [markdown]
# We can see Heath(Life Expectancy) is between the range 0-1

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df)

# %% [markdown]
# We can see freedom is between the range 0-0.7

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)

# %% [markdown]
# We can see Trust Government Corruption range between 0-0.6

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)

# %% [markdown]
# We can see Generosity ranging between 0-0.8

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Region']=le.fit_transform(df['Region'])

# %%
df['Region']
# Out:
# 0      9
# 1      9
# 2      9
# 3      9
# 4      5
#       ..
# 153    8
# 154    8
# 155    4
# 156    8
# 157    8
# Name: Region, Length: 158, dtype: int64

# %%
sns.scatterplot(x='Region',y='Happiness Score',data=df)

# %% [markdown]
# We can see Region is between range 0-9

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data=df)

# %% [markdown]
# droping ordinal data from the dataset

# %%
df.drop(['Country','Happiness Rank'],axis=1,inplace=True)

# %% [markdown]
# We can see Dystopia Residual range between 0-3.5

# %% [markdown]
# Correlation

# %%
df.corr()
# Out:
#                                  Region  Happiness Score  Standard Error  \
# Region                         1.000000        -0.176791       -0.022600
# Happiness Score               -0.176791         1.000000       -0.177254
# Standard Error                -0.022600        -0.177254        1.000000
# Economy (GDP per Capita)      -0.260139         0.780966       -0.217651
# Family                        -0.168533         0.740605       -0.120728
# Health (Life Expectancy)      -0.357508         0.724200       -0.310287
# Freedom                        0.092567         0.568211       -0.129773
# Trust (Government Corruption)  0.165040         0.395199       -0.178325
# Generosity                     0.273557         0.180319       -0.088439
# Dystopia Residual             -0.057276         0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Region                                        -0.260139 -0.168533
# ...

# %% [markdown]
# Correlation using Heatmap

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# Outcome of correlation

# %% [markdown]
# Region, and Standard error are negatively correlated with Hapiness Score while all the other columns are positively correlated.
#
# Economy is 78% corelated with happiness score and can e considered as a strong bond.Family is 74% correlated with the happiness score and can be considered as a strong bond. Health (Life Expectancy) is 72 % corelated to happiness score and can e considered as a good bond. Freedam is 58% corelated and can e considered as a good bond. Trust is 39% corelated and can be considered as a good bond. Dystopia Residual is 53% corelated and can be considered as a good bond.Generosity is 18 % corelated so can be considered as weak ond

# %% [markdown]
# Maximum Corr: Economy
# Minimum: Generosity

# %% [markdown]
# Describing Datasets

# %%
df.describe()
# Out:
#            Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# count  158.000000       158.000000      158.000000                158.000000
# mean     5.120253         5.375734        0.047885                  0.846137
# std      2.993321         1.145010        0.017146                  0.403121
# min      0.000000         2.839000        0.018480                  0.000000
# 25%      3.000000         4.526000        0.037268                  0.545808
# 50%      4.500000         5.232500        0.043940                  0.910245
# 75%      8.000000         6.243750        0.052300                  1.158448
# max      9.000000         7.587000        0.136930                  1.690420
#
#            Family  Health (Life Expectancy)     Freedom  \
# count  158.000000                158.000000  158.000000
# mean     0.991046                  0.630259    0.428615
# std      0.272369                  0.247078    0.150693
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.xticks(fontsize=12)
plt.title("Variable Summary")
plt.show()

# %% [markdown]
# Outcome of describing the datasets

# %% [markdown]
# total number of rows in dataselts
# 1.158 rows
# 2.11 columns

# %% [markdown]
# Region
# mean=
# std=
# min_value=
# max_value=

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         158 non-null    int64
#  1   Happiness Score                158 non-null    float64
#  2   Standard Error                 158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 12.5 KB

# %% [markdown]
# Outliers checking

# %%
collist=df.columns.values
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(10,15))
for i in range(0,len(collist)):
    plt.subplot(2,5,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# Standard error, family,trust(government corruption) has more outliers while Generosity and Dystopia Residual has less outliers

# %% [markdown]
# Skewness

# %%
df.skew()
# Out:
# Region                          -0.116119
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Outcome of skewness .Threshold value taken is -0.

# %%
sns.distplot(df['Region'])

# %% [markdown]
# data is not normalized

# %%
sns.distplot(df['Standard Error'])

# %% [markdown]
# data is not normalized

# %% [markdown]
# Removing Outliers

# %%
threshold=3
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157]), array([7, 2, 2, 2, 8, 4, 7, 9, 4]))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
print(df.shape)
print(df_new.shape)
# Out:
# (158, 10)
# (149, 10)

# %% [markdown]
# Percentage of lost data

# %%
p=((158-149)/158)*100

# %%
print("Loss Percentage=",p)
# Out:
# Loss Percentage= 5.69620253164557

# %% [markdown]
# checking if more outliers are there

# %%
z=np.abs(zscore(df_new))

# %%
print(np.where(z>3))
# Out:
# (array([ 2, 23, 38, 93]), array([7, 7, 2, 2]))

# %%
df_new=df_new[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (145, 10)

# %%
p=((158-145)*100)/158

# %%
print("Loss percentage=",p)
# Out:
# Loss percentage= 8.227848101265822

# %%
z=np.abs(zscore(df_new))

# %%
print(np.where(z>3))
# Out:
# (array([ 93, 144]), array([2, 2]))

# %%
df_new
# Out:
#      Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0         9            7.587         0.03411                   1.39651
# 1         9            7.561         0.04884                   1.30232
# 3         9            7.522         0.03880                   1.45900
# 4         5            7.427         0.03553                   1.32629
# 5         9            7.406         0.03140                   1.29025
# ..      ...              ...             ...                       ...
# 150       8            3.655         0.05141                   0.46534
# 151       8            3.587         0.04324                   0.25812
# 152       7            3.575         0.03084                   0.31982
# 154       8            3.340         0.03656                   0.28665
# 156       8            2.905         0.08658                   0.01530
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %%
x=df_new.iloc[:,3:]
y=df_new.iloc[:,1]

# %%
x
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# 5                     1.29025  1.31826                   0.88911  0.64169
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 3      7.522
# 4      7.427
# 5      7.406
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 145, dtype: float64

# %% [markdown]
# Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.52757101,  1.66443401,  1.5081949 , ...,  1.8710177 ,
#          0.66163007,  0.77608414],
#        [ 1.22379341,  2.01461854,  1.55109578, ...,  0.36547281,
#          1.55522799,  1.12974665],
#        [ 1.73428747,  1.54585061,  1.14560889, ...,  1.71628556,
#          1.01372509,  0.67640913],
#        ...,
#        [-1.36193232, -2.06866085, -1.36659181, ..., -0.16438112,
#          1.13173924, -0.30432936],
#        [-1.42977082, -1.99243904, -1.32381259, ..., -0.4095615 ,
#         -0.30304193, -0.91191109],
#        [-1.9337128 , -1.88931643, -1.56483446, ..., -0.11815536,
#         -0.16427042, -0.5314238 ]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 1.52757101,  1.66443401,  1.5081949 , ...,  1.8710177 ,
#          0.66163007,  0.77608414],
#        [ 1.22379341,  2.01461854,  1.55109578, ...,  0.36547281,
#          1.55522799,  1.12974665],
#        [ 1.73428747,  1.54585061,  1.14560889, ...,  1.71628556,
#          1.01372509,  0.67640913],
#        ...,
#        [-1.36193232, -2.06866085, -1.36659181, ..., -0.16438112,
#          1.13173924, -0.30432936],
#        [-1.42977082, -1.99243904, -1.32381259, ..., -0.4095615 ,
#         -0.30304193, -0.91191109],
#        [-1.9337128 , -1.88931643, -1.56483446, ..., -0.11815536,
#         -0.16427042, -0.5314238 ]])

# %% [markdown]
# since outcome is continuous we will use regression model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import mean_squared_error,mean_absolute_error,accuracy_score

# %% [markdown]
# Spliting the dataframe

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(y_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-63-5a20a108dc52> in <module>
#       1 for i in range(0,1000):
#       2     x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
# ----> 3     pred_train=lr.predict(x_train)
#       4     pred_test=lr.predict(y_train)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     200
#     201     def _decision_function(self, X):
# --> 202         check_is_fitted(self, "coef_")
#     203
# ...
