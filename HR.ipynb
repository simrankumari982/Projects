# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:/Users/Simran Kumari/Downloads/ibm-hr-analytics-employee-attrition-performance/hr.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
##data is deviated for most of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Employnumber is just an index and Employcount is irrelavant
df.drop(['EmployeeNumber','EmployeeCount'],axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# ...

# %% [markdown]
# # Visvalization

# %%
df['Over18'].unique
# Out:
# <bound method Series.unique of 0       Y
# 1       Y
# 2       Y
# 3       Y
# 4       Y
#        ..
# 1465    Y
# 1466    Y
# 1467    Y
# 1468    Y
# 1469    Y
# Name: Over18, Length: 1470, dtype: object>

# %%
#all the employees are over 18 hence column can be removed

# %%
cat_cols=[]
int_cols=[]
for i in df.columns:
    if df[i].dtype=='object':
        cat_cols.append(i)
    else:
        int_cols.append(i)

# %%
cat_cols
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
for i in cat_cols:
    sns.countplot(df[i])
    plt.show()

# %%
#yes and no are not equal, should be balanced
#Over18 can be removed

# %%
for i in int_cols:
    sns.distplot(df[i])
    plt.show()

# %%
#data is highly skewed

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat_cols:
    df[i]=le.fit_transform(df[i])

# %%
#checking outliers
for i in df.columns:
    sns.boxplot(df[i])
    plt.show()

# %%
##there are not much outliers in the whole data set

# %%
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# JobInvolvement            0.029820  -0.130016        0.039062   0.046135
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
##There is alot of coorelation in the data

# %%
df.drop(['Over18','StandardHours'],axis=1,inplace=True)

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
from scipy.stats import zscore
z=zscore(df)

# %%
df=df[(z<3).all(axis=1)]

# %%
df.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# ...

# %%
x=df.drop(['Attrition'],axis=1)
y=df['Attrition']

# %%
x.shape
# Out:
# (1387, 30)

# %%
y.shape
# Out:
# (1387,)

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=15)
x=pca.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()
x,y=smt.fit_resample(x,y)

# %%
x.shape,y.shape
# Out:
# ((2316, 15), (2316,))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
x_train=x
y_train=y
x_test=x
y_test=y
r_state=0
max_acc=0
lr=LogisticRegression()
for i in range(0,2000):
    tr_x,t_x,tr_y,t_y=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(tr_x,tr_y)
    pred=lr.predict(t_x)
    if accuracy_score(t_y,pred)>max_acc:
        x_train=tr_x
        x_test=t_x
        y_train=tr_y
        y_test=t_y
        r_state=i
        max_acc=accuracy_score(t_y,pred)
print("At random state",i,"max_acc is",max_acc)
# Out:
# At random state 1999 max_acc is 0.7370689655172413

# %%
from sklearn.model_selection import cross_val_score,KFold
def cvs(m):
    cv1=KFold(n_splits=5,shuffle=True)
    score=cross_val_score(m,x,y,cv=cv1,scoring='accuracy')
    print("Cross val score",score)
    print(score.mean())

# %%
from sklearn.model_selection import GridSearchCV
def hypertuning(params,model):
    gd=GridSearchCV(model,params,cv=5)
    gd.fit(x,y)
    print(gd.best_params_)

# %%
from sklearn.svm import SVC
params_svc={
    'kernel':['poly','linear','rbf','sigmoid'],'degree':[1,3,5,7],'gamma':['auto','scale'],'shrinking':[True,False]}
hypertuning(params_svc,SVC())
# Out:
# {'degree': 1, 'gamma': 'scale', 'kernel': 'rbf', 'shrinking': True}

# %%
svc=SVC(degree=1,gamma='scale',kernel='rbf',shrinking=True)
fun(svc)
cvs(svc)
# Out:
# Accuracy score 0.8491379310344828
# Confusion matrix
#  [[183  45]
#  [ 25 211]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       228
#            1       0.82      0.89      0.86       236
#
#     accuracy                           0.85       464
#    macro avg       0.85      0.85      0.85       464
# weighted avg       0.85      0.85      0.85       464
#
# Cross val score [0.83405172 0.85961123 0.83801296 0.80993521 0.79697624]
# 0.8277174722573918

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print("Accuracy score",accuracy_score(y_test,pred))
    print("Confusion matrix \n",confusion_matrix(y_test,pred))
    print("Classification report \n",classification_report(y_test,pred))

# %%
CVS=[0.82]
acc=[0.84]
model=['SVC']

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
params_dtc={'criterion':['gini','entropy'],'splitter':['random','best'],'max_depth':[None,1,2,3],'min_samples_split':[2,3,4]}
hypertuning(params_dtc,dtc)
# Out:
# {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 4, 'splitter': 'random'}

# %%
dtc=DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=4,splitter='random')
fun(dtc)
cvs(dtc)
# Out:
# Accuracy score 0.790948275862069
# Confusion matrix
#  [[171  57]
#  [ 40 196]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       228
#            1       0.77      0.83      0.80       236
#
#     accuracy                           0.79       464
#    macro avg       0.79      0.79      0.79       464
# weighted avg       0.79      0.79      0.79       464
#
# Cross val score [0.7737069  0.76457883 0.76889849 0.72354212 0.73650108]
# 0.7534454829820512

# %%
CVS.append(0.79)
acc.append(0.75)
model.append("DTC")

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
params_knn={'n_neighbors':[5,7,9,11],'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree','brute'],'leaf_size':[30,40,50]}
hypertuning(params_knn,knn)
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 5, 'weights': 'distance'}

# %%
knn=KNeighborsClassifier(algorithm='auto',leaf_size=30,n_neighbors=5,weights='distance')
fun(knn)
cvs(knn)
# Out:
# Accuracy score 0.8146551724137931
# Confusion matrix
#  [[143  85]
#  [  1 235]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.63      0.77       228
#            1       0.73      1.00      0.85       236
#
#     accuracy                           0.81       464
#    macro avg       0.86      0.81      0.81       464
# weighted avg       0.86      0.81      0.81       464
#
# Cross val score [0.78448276 0.79697624 0.74730022 0.81209503 0.8012959 ]
# 0.7884300290459522

# %%
CVS.append(0.78)
model.append("KNN")

# %%
acc.append(0.81)

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,HistGradientBoostingClassifier
from sklearn.tree import ExtraTreeClassifier
rf=RandomForestClassifier()
etc=ExtraTreeClassifier()
ada=AdaBoostClassifier()
Gd=GradientBoostingClassifier()
HGd=HistGradientBoostingClassifier()

# %%
params_rf={'n_estimators':[10,20,30,50],
           'criterion':['gini', 'entropy'],
           'max_depth':[None,1,2,3],
           'min_samples_split':[2,3,4]}
hypertuning(params_rf,rf)
# Out:
# {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}

# %%
rf=RandomForestClassifier(criterion='gini',max_depth=None,min_samples_split=2,n_estimators=50)

# %%
fun(rf)
cvs(rf)
# Out:
# Accuracy score 0.8857758620689655
# Confusion matrix
#  [[201  27]
#  [ 26 210]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       228
#            1       0.89      0.89      0.89       236
#
#     accuracy                           0.89       464
#    macro avg       0.89      0.89      0.89       464
# weighted avg       0.89      0.89      0.89       464
#
# Cross val score [0.90086207 0.88552916 0.87041037 0.85097192 0.86609071]
# 0.8747728457585462

# %%
CVS.append(0.88)
model.append("random forest")
acc.append(0.87)

# %%
params_etc={'criterion':['gini','entropy'],
            'splitter':['random','best'],
            'max_depth':[None,1,2,3],
            'min_samples_split':[2,3,4]}
hypertuning(params_etc,etc)
# Out:
# {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'splitter': 'best'}

# %%
etc=ExtraTreeClassifier(criterion='gini',max_depth=None,min_samples_split=2,splitter='best')
fun(etc)
cvs(etc)
# Out:
# Accuracy score 0.7887931034482759
# Confusion matrix
#  [[178  50]
#  [ 48 188]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       228
#            1       0.79      0.80      0.79       236
#
#     accuracy                           0.79       464
#    macro avg       0.79      0.79      0.79       464
# weighted avg       0.79      0.79      0.79       464
#
# Cross val score [0.78232759 0.75809935 0.76457883 0.74946004 0.75161987]
# 0.7612171371117896

# %%
acc.append(0.78)
CVS.append(0.76)
model.append('Extra tree')

# %%
params_ada={'n_estimators':[10,20,30,50],'learning_rate':[1,0.9,0.8],'algorithm':['SAMME', 'SAMME.R'],'random_state':[43,33,56]}
hypertuning(params_ada,ada)
# Out:
# {'algorithm': 'SAMME.R', 'learning_rate': 1, 'n_estimators': 50, 'random_state': 43}

# %%
ada=AdaBoostClassifier(algorithm='SAMME.R',learning_rate=1,n_estimators=50,random_state=43)

# %%
fun(ada)
cvs(ada)
# Out:
# Accuracy score 0.7133620689655172
# Confusion matrix
#  [[160  68]
#  [ 65 171]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.71      0.70      0.71       228
#            1       0.72      0.72      0.72       236
#
#     accuracy                           0.71       464
#    macro avg       0.71      0.71      0.71       464
# weighted avg       0.71      0.71      0.71       464
#
# Cross val score [0.70258621 0.7300216  0.72354212 0.74514039 0.71922246]
# 0.7241025545542563

# %%
CVS.append(0.72)
acc.append(0.71)
model.append('Ada Boost')

# %%
res=pd.DataFrame()
res['Models']=model
res['CVS']=CVS
res['r2']=acc
diff=[]
for i in range(0,len(acc)):
    diff.append(acc[i]-CVS[i])
res['diff']=diff
res
# Out:
#           Models   CVS    r2  diff
# 0            SVC  0.82  0.84  0.02
# 1            DTC  0.79  0.75 -0.04
# 2            KNN  0.78  0.81  0.03
# 3  random forest  0.88  0.87 -0.01
# 4     Extra tree  0.76  0.78  0.02
# 5      Ada Boost  0.72  0.71 -0.01

# %%
fun(lr)
cvs(lr)
# Out:
# Accuracy score 0.7370689655172413
# Confusion matrix
#  [[167  61]
#  [ 61 175]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73       228
#            1       0.74      0.74      0.74       236
#
#     accuracy                           0.74       464
#    macro avg       0.74      0.74      0.74       464
# weighted avg       0.74      0.74      0.74       464
#
# Cross val score [0.67025862 0.65010799 0.67386609 0.66090713 0.69114471]
# 0.6692569077232442

# %%
#Best model is rf since accuracy is high and difference between acc and cvs is least

# %%
import pickle
filename='hr.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
predict=rf.predict(x_test)

# %%
output=pd.DataFrame()
output['Actual']=y_test
output['Predicted']=predict
output
# Out:
#       Actual  Predicted
# 738        0          0
# 1697       1          1
# 1351       0          0
# 1454       1          1
# 1678       1          1
# ...      ...        ...
# 1382       0          0
# 1720       1          1
# 57         0          0
# 1021       1          1
# 2104       1          1
#
# [464 rows x 2 columns]

# %%
output.to_csv('HR_prediction.csv')
