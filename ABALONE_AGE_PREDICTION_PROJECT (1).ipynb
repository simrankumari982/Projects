# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('abalone_dataset.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
sns.pairplot(df)

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
sns.countplot(df['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# Diameter              0.893162        0.899724      0.905330  0.574660
# Height                0.774972        0.798319      0.817338  0.557467
# Whole weight          0.969405        0.966375      0.955355  0.540390
# Shucked weight        1.000000        0.931961      0.882617  0.420884
# Viscera weight        0.931961        1.000000      0.907656  0.503819
# Shell weight          0.882617        0.907656      1.000000  0.627574
# Rings                 0.420884        0.503819      0.627574  1.000000

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# Diameter              0.893162        0.899724      0.905330  0.574660
# Height                0.774972        0.798319      0.817338  0.557467
# Whole weight          0.969405        0.966375      0.955355  0.540390
# Shucked weight        1.000000        0.931961      0.882617  0.420884
# Viscera weight        0.931961        1.000000      0.907656  0.503819
# Shell weight          0.882617        0.907656      1.000000  0.627574
# Rings                 0.420884        0.503819      0.627574  1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# all the columns are highly correlated to the target column

# %% [markdown]
# # Describing Dataset

# %%
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
plt.figure(figsize=(15,21))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show()

# %% [markdown]
# # Outcomes of describe of dataset

# %% [markdown]
# from the above plotting we are determining mean, standard deviation, minimum and maximum value of each column. It helps in the data cleaning.

# %% [markdown]
# Total no of rows in the datasets:
#
# 1. 4177 rows
# 2. 8 columns

# %% [markdown]
# Length
#
# 1. Mean=0.523992
# 2. std=0.120093
# 3. min=0.075
# 4. max=0.815

# %% [markdown]
# Diameter
#
# 1. Mean=0.407881
# 2. std=0.099240
# 3. min=0.055
# 4. max=0.65

# %% [markdown]
# Heigth
#
# 1. Mean=0.139516
# 2. std=0.041827
# 3. min=0
# 4. max=1.13

# %% [markdown]
# Whole Weight
#
# 1. Mean=0.828742
# 2. std=0.490389
# 3. min=0.002
# 4. max=2.825500

# %% [markdown]
# Shucked Weight
#
# 1. Mean=0.359367
# 2. std=0.221963
# 3. min=0.001
# 4. max=1.488000

# %% [markdown]
# Viscera Weight
#
# 1. Mean=0.238831
# 2. std=0.139203
# 3. min=0.000500
# 4. max=0.760000

# %% [markdown]
# Shell Weight
#
# 1. Mean=0.238831
# 2. std=0.139203
# 3. min=0.001500
# 4. max=1.005000

# %% [markdown]
# # Outlier Checking

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# Only height has less outliers

# %% [markdown]
# # Normal Distribution Curve

# %%
collist=df.columns

# %%
for i in collist:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# data is not normalized

# %% [markdown]
# data is highly skewed

# %%
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
# Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (4177, 9)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
#        2436, 2459, 2471, 2544, 2623, 2624, 2624, 2624, 2625, 2709, 2710,
#        2710, 2810, 2810, 2811, 2811, 2811, 2862, 2863, 2863, 2863, 3007,
#        3008, 3140, 3148, 3149, 3149, 3151, 3151, 3188, 3193, 3280, 3359,
#        3427, 3427, 3427, 3599, 3599, 3628, 3713, 3715, 3715, 3715, 3715,
#        3800, 3837, 3899, 3899, 3902, 3924, 3930, 3944, 3961, 3962, 3996,
#        4145, 4148], dtype=int64), array([8, 8, 7, 8, 7, 7, 7, 4, 5, 7, 7, 8, 8, 7, 6, 8, 8, 1, 2, 3, 1, 2,
#        1, 2, 1, 8, 8, 7, 8, 8, 8, 8, 8, 7, 8, 8, 4, 7, 8, 8, 8, 8, 8, 8,
#        8, 8, 8, 8, 8, 1, 2, 8, 8, 8, 8, 8, 8, 8, 2, 1, 2, 1, 2, 1, 2, 8,
#        8, 8, 8, 4, 5, 7, 6, 4, 5, 4, 5, 5, 5, 5, 6, 5, 6, 4, 5, 6, 7, 4,
#        5, 3, 3, 5, 5, 6, 5, 4, 5, 6, 7, 1, 2, 5, 5, 5, 6, 6, 5, 4, 5, 6,
#        4, 5, 6, 5, 5, 1, 1, 2, 3, 7, 7, 8, 1, 2, 7, 7, 8, 8, 8, 8, 7, 8,
#        7, 8, 8, 4, 6, 8, 8, 8, 8, 7, 1, 8, 8, 8, 5, 4, 4, 5, 6, 5, 6, 5,
#        6, 5, 6, 4, 5, 6, 5, 4, 5, 6, 5, 7, 8, 7, 7, 8, 7, 8, 7, 8, 8, 8,
#        4, 5, 6, 4, 5, 6, 5, 4, 5, 6, 7, 4, 2, 1, 2, 1, 8, 8, 8, 5, 5, 3,
#        7, 6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (4027, 9)

# %% [markdown]
# # Percentage of data loss

# %%
loss_prcnt=(4177-4027)/4177*100
print(loss_prcnt)
# Out:
# 3.5910940866650707

# %% [markdown]
# # Checking multi colinearity

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %%
import scipy.stats as st
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor as viff
def calc_vif(x1):
    vif=pd.DataFrame()
    vif["variables"]=x1.columns
    vif['VIF Factor']=[viff(x1.values,i) for i in range(x1.shape[1])]
    return(vif)

# %%
calc_vif(x)
# Out:
#         variables  VIF Factor
# 0             Sex    2.586539
# 1          Length  711.017756
# 2        Diameter  762.862946
# 3          Height   92.050181
# 4    Whole weight  441.600560
# 5  Shucked weight  108.511496
# 6  Viscera weight   65.669278
# 7    Shell weight   94.849108

# %%
df_new.drop(['Length','Shucked weight'],axis=1,inplace=True)
x=df_new.iloc[:,:-1]

# %% [markdown]
# Transforming data and removing skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.13432919, -0.54337947, -1.15893308, -0.57513463, -0.68803217,
#         -0.58635376],
#        [ 1.13432919, -1.40113174, -1.28040611, -1.35404959, -1.33285416,
#         -1.33271691],
#        [-1.31306782,  0.03716259, -0.12830502, -0.18449788, -0.24037305,
#         -0.08021413],
#        ...,
#        [ 1.13432919,  0.70592133,  1.94363286,  0.85343427,  1.08965131,
#          0.66363183],
#        [-1.31306782,  0.8377131 ,  0.28606972,  0.69738476,  0.87642835,
#          0.57752029],
#        [ 1.13432919,  1.85550496,  1.62558351,  2.14577531,  1.73214622,
#          1.85675543]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.13432919, -0.54337947, -1.15893308, -0.57513463, -0.68803217,
#         -0.58635376],
#        [ 1.13432919, -1.40113174, -1.28040611, -1.35404959, -1.33285416,
#         -1.33271691],
#        [-1.31306782,  0.03716259, -0.12830502, -0.18449788, -0.24037305,
#         -0.08021413],
#        ...,
#        [ 1.13432919,  0.70592133,  1.94363286,  0.85343427,  1.08965131,
#          0.66363183],
#        [-1.31306782,  0.8377131 ,  0.28606972,  0.69738476,  0.87642835,
#          0.57752029],
#        [ 1.13432919,  1.85550496,  1.62558351,  2.14577531,  1.73214622,
#          1.85675543]])

# %% [markdown]
# # Using Regression Models

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor  
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVR
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
lr=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=43,test_size=0.20)
lr.fit(x_train,y_train)
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
print("mean squared error",mean_squared_error(pred_test,y_test))
print(r2_score(pred_test,y_test))
# Out:
# mean squared error 4.333030596308985
# -0.12337947937634453

# %% [markdown]
# # Lasso and Ridge

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.45281255318966096

# %%
ls.coef_
# Out:
# array([-3.55764638e-03, -4.41849591e-01,  7.71014382e-01, -2.26887282e+00,
#         1.15777455e-01,  3.64093860e+00])

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.0001)

# %%
rd.score(x_train,y_train)
# Out:
# 0.4528127552388833

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr.fit(x_train,y_train)
enr.score(x_train,y_train)
# Out:
# 0.4528122895444777

# %%
kernellist=['linear','rbf','poly']
for i in kernellist:
    svr=SVR(kernel=i)
    svr.fit(x_train,y_train)
    pred=svr.predict(x_test)
    print(mean_squared_error(y_test,pred))
# Out:
# 4.54234536635636
# 4.094636907324739
# 5.590894503558537

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(criterion='mse')
dtr.fit(x_train,y_train)
print("DTC Score",dtr.score(x_train,y_train))

pred_dtc=dtr.predict(x_test)
print("r2 score",r2_score(y_test,pred_dtc))
print("mean_squared_error",mean_squared_error(y_test,pred_dtc))
# Out:
# DTC Score 1.0
# r2 score -0.07365026319217005
# mean_squared_error 8.53970223325062

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
print("KN Score",knn.score(x_train,y_train))

pred_knn=knn.predict(x_test)
print("r2 score",r2_score(y_test,pred_knn))
print("mean_squared_error",mean_squared_error(y_test,pred_knn))
# Out:
# KN Score 0.6315578104380475
# r2 score 0.4130940673723186
# mean_squared_error 4.668188585607941

# %%
from sklearn.svm import SVR

# %%
svr=SVR()
svr.fit(x_train,y_train)
print("SVR Score",svr.score(x_train,y_train))
pred_svr=svr.predict(x_test)
print("r2 Score",r2_score(y_test,pred_svr))
print("mean squared error",mean_squared_error(y_test,pred_svr))
# Out:
# SVR Score 0.4915526236794009
# r2 Score 0.4852035968996343
# mean squared error 4.094636907324739

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
print("SGD score",sgd.score(x_train,y_train))
pred_sgd=sgd.predict(x_test)
print("r2 Score",r2_score(y_test,pred_sgd))
print("mean squared error",mean_squared_error(y_test,pred_sgd))
# Out:
# SGD score 0.45012836164352876
# r2 Score 0.45270927267694805
# mean squared error 4.353093373685961

# %% [markdown]
# # Approaching Ensemble Method

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
print(rf.score(x_train,y_train))
pred_rf=rf.predict(x_test)
print("r2 Score",r2_score(y_test,pred_rf))
print("mean squared error",mean_squared_error(y_test,pred_rf))
# Out:
# 0.9272718194268706
# r2 Score 0.48851944123022095
# mean squared error 4.068263027295285

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor(n_estimators=50,random_state=42)
ada.fit(x_train,y_train)
print(ada.score(x_train,y_train))
pred_ada=ada.predict(x_test)
print("r2 Score",r2_score(y_test,pred_ada))
print("mean squared error",mean_squared_error(y_test,pred_ada))
# Out:
# 0.38017793875199013
# r2 Score 0.3792624198836949
# mean squared error 4.937281981770444

# %% [markdown]
# Saving the best model

# %%
import joblib
joblib.dump(dtr,'dtrmodel.obj')
dtrloadmodel=joblib.load('dtrmodel.obj')
dtrloadmodel.predict(x_test)
# Out:
# array([12., 12., 14., 15.,  7.,  8.,  8.,  8.,  9., 10., 10., 10., 16.,
#        10.,  8., 15.,  7., 11., 17., 11., 10.,  7.,  8., 10., 10.,  8.,
#        10., 11.,  6.,  9.,  8.,  6.,  8., 10.,  8.,  9.,  9.,  7., 11.,
#        13.,  9., 11., 10., 14., 13., 17., 14.,  8., 12.,  8., 10.,  9.,
#         9.,  9., 10., 17., 10., 11.,  8., 12., 16., 14., 11., 11.,  7.,
#        13.,  7., 10., 15.,  6.,  9.,  8., 14., 12., 16.,  8.,  6.,  6.,
#        11.,  8., 11., 15.,  9., 10., 12.,  7., 12., 11.,  8.,  9., 10.,
#         8.,  8.,  8., 10., 18., 10., 12., 14., 11., 10.,  9., 10.,  7.,
#         8.,  5., 12., 11.,  6., 11., 10.,  9., 16.,  8., 10., 10., 12.,
#         9.,  9., 10., 11.,  6.,  8., 10., 10.,  7.,  9., 17.,  9., 12.,
#         9.,  5., 10., 11.,  8., 10., 18., 12., 10.,  7.,  9., 15.,  8.,
#         8., 12.,  7.,  7.,  5.,  8.,  5., 15.,  8., 13., 10., 10.,  9.,
#        10., 11.,  9., 11., 10., 12.,  8.,  6., 13.,  8., 11.,  8.,  9.,
#        16., 11.,  7., 10.,  5.,  9., 10.,  8., 10.,  8.,  9., 11.,  8.,
#         9., 14.,  6., 12., 10., 13., 13.,  7.,  7., 13., 10., 10., 10.,
#        12., 10., 10.,  7., 10.,  8., 11.,  9., 15.,  8., 12., 17., 10.,
#         8.,  9., 18., 10.,  6., 11.,  6., 12.,  7., 12., 11., 17.,  7.,
#         9., 12.,  7., 14., 18., 10.,  9., 12., 12.,  7., 10., 18., 17.,
#        14.,  7., 19.,  9., 12., 10., 11.,  8.,  5.,  8., 17.,  9., 14.,
#        14.,  9.,  6., 14., 11.,  6.,  5., 17.,  7.,  6., 10.,  7., 10.,
#         8., 17., 10., 17.,  9.,  7., 10., 13.,  8., 11., 11.,  6.,  8.,
#        11.,  7., 18., 11., 11.,  7.,  8., 10.,  8., 12.,  8., 10., 10.,
#        10.,  9.,  8., 12., 11.,  7.,  8., 10., 14., 10.,  7., 14., 11.,
#         8.,  8.,  6.,  5.,  6., 13., 17., 11., 10.,  8., 10.,  9., 13.,
#         8.,  7.,  8.,  8.,  8., 10.,  7.,  9.,  4.,  7.,  6., 11., 12.,
#        12.,  9., 10.,  8., 14.,  9., 16.,  9.,  8.,  9.,  9., 11.,  9.,
#        10.,  9., 17., 18., 11., 11., 11.,  8., 10., 10., 10.,  5.,  4.,
#        11., 17., 11.,  9., 11.,  9., 10.,  9.,  9.,  8.,  8., 16., 15.,
#        14., 11.,  7., 14., 12., 10.,  6., 12., 10., 12., 11., 12.,  8.,
#        10., 11., 10., 14., 13., 10.,  8., 11.,  7., 12., 10., 13.,  9.,
#         9., 10., 13.,  8.,  9.,  9.,  9., 15., 10., 10.,  7., 12.,  8.,
#         7., 10.,  6., 13., 12.,  8.,  4., 10., 15.,  6.,  6., 11., 10.,
#        11.,  8.,  9., 11., 11., 13.,  6., 10.,  8.,  8., 11.,  9., 13.,
#        10.,  8., 10.,  8., 17.,  6.,  9., 13., 12., 15., 10., 13.,  5.,
#         8.,  6.,  9.,  5.,  6.,  7., 19., 11.,  8., 14.,  9.,  9.,  8.,
#         9.,  8., 10.,  7., 10., 10., 13.,  8.,  9.,  6.,  8.,  9.,  7.,
#        13., 10., 12.,  6.,  4.,  5., 18.,  9.,  8., 18.,  7.,  9., 10.,
#        14.,  9.,  6.,  8., 14., 14., 14.,  9., 13.,  9.,  8.,  8.,  8.,
#         8., 16.,  7., 10.,  7., 10., 13., 16., 18.,  9.,  8.,  7.,  9.,
#        15.,  9.,  6.,  9.,  9., 14., 10.,  8., 11.,  8.,  7., 10., 13.,
#         7.,  6.,  9.,  8., 15.,  8.,  8., 18.,  9.,  8., 13., 15., 11.,
#        10., 11.,  7.,  9.,  4.,  5., 10.,  6., 11., 10., 11.,  6., 15.,
#        11.,  5., 11.,  8., 12., 10.,  6.,  8., 10., 13., 13.,  8.,  9.,
#        19.,  6., 15., 10., 11.,  8.,  8., 10.,  7.,  9., 14.,  8., 11.,
#        15.,  8.,  9., 11.,  8., 10.,  8.,  8., 10.,  6.,  9.,  8.,  7.,
#         6., 10., 10.,  7., 11., 11.,  9.,  8., 10., 15., 10., 12., 13.,
#        11., 10.,  7.,  7.,  7.,  6., 17., 10., 12.,  8.,  9.,  7., 10.,
#         9., 10.,  9., 11., 11.,  3.,  8., 11.,  6., 12., 16.,  9.,  7.,
#        14.,  8., 10.,  8., 10., 14.,  6., 13., 19.,  8., 11.,  8.,  8.,
#        10.,  6., 11., 11.,  7., 19.,  8., 11., 10.,  9.,  8.,  9., 11.,
#         8., 11., 11., 10.,  7.,  6., 18.,  9., 12.,  8., 16., 10., 10.,
#         6.,  4., 19., 12.,  7., 12.,  9., 10., 12., 11., 15.,  8.,  6.,
#         7.,  9.,  4.,  8.,  8., 13.,  9., 14., 15.,  8., 10.,  7., 10.,
#         7., 19.,  7.,  5., 17., 12.,  8., 12.,  6.,  4., 18.,  9.,  7.,
#        13., 14., 10.,  8., 13., 12.,  9., 10., 10.,  7., 11.,  6.,  9.,
#         6.,  9.,  8., 12.,  9., 10.,  9.,  6., 11., 12., 11., 14.,  6.,
#         6.,  6., 12.,  8.,  6.,  7.,  9.,  9.,  5., 12.,  7., 12.,  6.,
#        10.,  8.,  6.,  9., 17., 10.,  9., 11., 13., 11., 10., 11., 17.,
#        10.,  8.,  8.,  9., 10., 16., 11., 13.,  7.,  8.,  9., 13.,  9.,
#        16.,  8., 11.,  8.,  9.,  9.,  8.,  8., 12.,  8.,  9.,  7., 12.,
#        14.,  7., 11., 10.,  8.,  8., 14., 12., 10., 11.,  9., 11.,  8.,
#         8., 10., 10., 11., 12.,  8.,  9.,  8., 14., 10., 14., 11.,  7.])
